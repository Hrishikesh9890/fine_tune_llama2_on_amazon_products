# %%
# !pip install -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.33.1 trl==0.4.7

# %%
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
amazon_categories='/kaggle/input/amazon-products/amazon_categories.csv'
amazon_products='/kaggle/input/amazon-products/amazon_products.csv'

# %%
df_category=pd.read_csv(amazon_categories)

# %%
df_product=pd.read_csv(amazon_products)

# %%
df_product.head(2)
df_category.head(4)
# Out:
#    id                category_name
# 0   1     Beading & Jewelry Making
# 1   2            Fabric Decorating
# 2   3  Knitting & Crochet Supplies
# 3   4         Printmaking Supplies

# %%
df_category.isnull().sum()/len(df_category)
# Out:
# id               0.0
# category_name    0.0
# dtype: float64

# %%
df_product.isnull().sum()/len(df_product)
# Out:
# asin                 0.000000e+00
# title                7.010966e-07
# imgUrl               0.000000e+00
# productURL           0.000000e+00
# stars                0.000000e+00
# reviews              0.000000e+00
# price                0.000000e+00
# listPrice            0.000000e+00
# category_id          0.000000e+00
# isBestSeller         0.000000e+00
# boughtInLastMonth    0.000000e+00
# dtype: float64

# %%
df_product=df_product.dropna()

# %%
df_product.isnull().sum()/len(df_product)
# Out:
# asin                 0.0
# title                0.0
# imgUrl               0.0
# productURL           0.0
# stars                0.0
# reviews              0.0
# price                0.0
# listPrice            0.0
# category_id          0.0
# isBestSeller         0.0
# boughtInLastMonth    0.0
# dtype: float64

# %%
merged_df = pd.merge( df_category,df_product,left_on='id', right_on='category_id')

# %%
merged_df = merged_df.sample(n=50000, random_state=33)

# %%
merged_df.isnull().sum()/len(merged_df)*100
# Out:
# id                   0.0
# category_name        0.0
# asin                 0.0
# title                0.0
# imgUrl               0.0
# productURL           0.0
# stars                0.0
# reviews              0.0
# price                0.0
# listPrice            0.0
# category_id          0.0
# isBestSeller         0.0
# boughtInLastMonth    0.0
# dtype: float64

# %%
merged_df["text"] = merged_df.apply(lambda row: str(row['title']) + " ->: " + str(row['category_name']), axis=1)

# %%
merged_df['text']
# Out:
# 1361595    When Calls The Heart Hope Valley Christmas Col...
# 626897     Hat – Trucker Mesh Snapback Baseball Cap ->: M...
# 975844     Tampon Holder for Bathroom with Lids Wood and ...
# 500534     Girls' Big School Uniform Twill Skinny Pants, ...
# 1336210    Set of 4: 5" Mercedes Benz SLS AMG 1:36 Scale ...
#                                  ...
# 148484     NOVSIGHT 9005 H11 Led Headlight Bulbs High Low...
# 230150     Karley Bassinet in Onyx, Lightweight Portable ...
# 935675     5Aplusreprap Heatbed Leveling 4Pcs Aluminum Ha...
# 462286     Boys' Big Performance Tween Boxer Briefs Under...
# 952388     Safetec 34815 SaniZide Plus Germicidal Solutio...
# Name: text, Length: 50000, dtype: object

# %%
from sklearn.model_selection import train_test_split
train_df,test_df=train_test_split(merged_df,test_size=0.3,random_state=42)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from datasets import Dataset,DatasetDict
train_dataset_dict=DatasetDict({
    "train":Dataset.from_pandas(train_df),
})

# %%
import os
import torch
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
)
from peft import LoraConfig, PeftModel
from trl import SFTTrainer

# %%
# The model that you want to train from the Hugging Face hub
model_name = "NousResearch/Llama-2-7b-chat-hf"

################################################################################
# QLoRA parameters
################################################################################

# LoRA attention dimension
lora_r = 64

# Alpha parameter for LoRA scaling
lora_alpha = 16

# Dropout probability for LoRA layers
lora_dropout = 0.1

################################################################################
# bitsandbytes parameters
################################################################################

# Activate 4-bit precision base model loading
use_4bit = True

# Compute dtype for 4-bit base models
bnb_4bit_compute_dtype = "float16"

# Quantization type (fp4 or nf4)
bnb_4bit_quant_type = "nf4"

# Activate nested quantization for 4-bit base models (double quantization)
use_nested_quant = False

################################################################################
# TrainingArguments parameters
################################################################################

# Output directory where the model predictions and checkpoints will be stored
output_dir = "./results"

# Number of training epochs
num_train_epochs = 1

# Enable fp16/bf16 training (set bf16 to True with an A100)
fp16 = False
bf16 = False

# Batch size per GPU for training
per_device_train_batch_size = 4

# Batch size per GPU for evaluation
per_device_eval_batch_size = 4

# Number of update steps to accumulate the gradients for
gradient_accumulation_steps = 1

# Enable gradient checkpointing
gradient_checkpointing = True

# Maximum gradient normal (gradient clipping)
max_grad_norm = 0.3

# Initial learning rate (AdamW optimizer)
learning_rate = 2e-4

# Weight decay to apply to all layers except bias/LayerNorm weights
weight_decay = 0.001

# Optimizer to use
optim = "paged_adamw_32bit"

# Learning rate schedule
lr_scheduler_type = "cosine"

# Number of training steps (overrides num_train_epochs)
max_steps = 120

# Ratio of steps for a linear warmup (from 0 to learning rate)
warmup_ratio = 0.03

# Group sequences into batches with same length
# Saves memory and speeds up training considerably
group_by_length = True

# Save checkpoint every X updates steps
save_steps = 0

# Log every X updates steps
logging_steps = 25

################################################################################
# SFT parameters
################################################################################

# Maximum sequence length to use
max_seq_length = None

# Pack multiple short examples in the same input sequence to increase efficiency
packing = False

# Load the entire model on the GPU 0
device_map = {"": 0}

# %%
tokenizer=AutoTokenizer.from_pretrained(model_name,trust_remote_code=True)
tokenizer.pad_token=tokenizer.eos_token
# Out:
# tokenizer_config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]

# %%
import transformers
pipeline=transformers.pipeline(
    "text-generation",
    model=model_name,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto"
)

print("lets check what model predict before finetunning .")

sequences =pipeline(
        ["Luggage Sets Expandable Lightweight Suitcases with Wheels PC+ABS Durable Travel Luggage TSA Lock Navy Blue 4pcs ->","Tranverz S - Triple Denim ->","Original X-box Series X Controller compatible with X-box One/Series S/X, PC | Custom X-box One Controller | Printed in USA with Advanced HYDROGRAPHIC Technology (NOT JUST A SKIN or STICKER) ->:"],
          max_length=200,
          do_sample=True,
          top_k=10,
          num_return_sequences=1,
          eos_token_id=tokenizer.eos_token_id,
)

for seq in sequences:
  print(f"Result : {seq[0]['generated_text']}")
# Out:
# config.json:   0%|          | 0.00/583 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/179 [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1417: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# lets check what model predict before finetunning .
# Result : Luggage Sets Expandable Lightweight Suitcases with Wheels PC+ABS Durable Travel Luggage TSA Lock Navy Blue 4pcs -> Great for travel.
# I have found most affordable price of Explore the World – 4 Piece Luggage Set – Expandable Lightweight Suitcases with Wheels PC+ABS Durable Travel Luggage TSA Lock Navy Blue 4pcs -> Great for travel from Amazon store. It offers fast and reliable shipping. Explore the World – 4 Piece Luggage Set – Expandable Lightweight Suitcases with Wheels PC+ABS Durable Travel Luggage TSA Lock Navy Blue 4pcs -> Great for travel is good quality product at affordable price. You will get proper dwelling delivery. Shop below for availability.
# Result : Tranverz S - Triple Denim -> S-Logo Black. 100% Cotton. Made in Italy.
# Product measurements were taken using size 32, please note that measurements may vary slightly by size.
# Result : Original X-box Series X Controller compatible with X-box One/Series S/X, PC | Custom X-box One Controller | Printed in USA with Advanced HYDROGRAPHIC Technology (NOT JUST A SKIN or STICKER) ->: Amazon.
# The new generation of gaming controllers from Razer has been designed to provide an immersive gaming experience. The Razer Raiju Ultimate is a high-end controller designed for PC gamers who demand the best possible performance. It features interchangeable paddle sets, customizable backlit buttons, and a 32-bit ARM processor that can be programmed using Razer's Synapse software.
# Razer Raiju Ultimate Wireless Gaming Controller - For PC | Customizable Backlit Buttons | 32-Bit ARM Processor | Interchangeable Paddle Sets | Long Battery Life | Compat

# %%
# Load tokenizer and model with QLoRA configuration
compute_dtype = getattr(torch, bnb_4bit_compute_dtype)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)

# Check GPU compatibility with bfloat16
if compute_dtype == torch.float16 and use_4bit:
    major, _ = torch.cuda.get_device_capability()
    if major >= 8:
        print("=" * 80)
        print("Your GPU supports bfloat16: accelerate training with bf16=True")
        print("=" * 80)

# Load base model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map=device_map
)
model.config.use_cache = False
model.config.pretraining_tp = 1

# Load LLaMA tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right" # Fix weird overflow issue with fp16 training

# Load LoRA configuration
peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
)

# Set training parameters
training_arguments = TrainingArguments(
    output_dir=output_dir,
    num_train_epochs=num_train_epochs,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    weight_decay=weight_decay,
    fp16=fp16,
    bf16=bf16,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=group_by_length,
    lr_scheduler_type=lr_scheduler_type,
    report_to="tensorboard"
)

# Set supervised fine-tuning parameters


trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset_dict['train'],
    peft_config=peft_config,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
    packing=packing,
)

# Train model
trainer.train()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/peft/utils/other.py:102: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/trl/trainer/sft_trainer.py:159: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
#   0%|          | 0/35 [00:00<?, ?ba/s]
# You are using 8-bit optimizers with a version of `bitsandbytes` < 0.41.1. It is recommended to update your version as a major bug has been fixed in 8-bit optimizers.
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='120' max='120' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [120/120 05:54, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>2.870700</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>2.665700</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>2.484600</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>2.490500</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=120, training_loss=2.572362995147705, metrics={'train_runtime': 364.8194, 'train_samples_per_second': 2.631, 'train_steps_per_second': 0.329, 'total_flos': 1137165959823360.0, 'train_loss': 2.572362995147705, 'epoch': 0.03})

# %%
lst_test_data_short=list(test_df['text'])

# %%
len(lst_test_data_short)
# Out:
# 15000

# %%
sample_size=35
lst_test_data_short=lst_test_data_short[:sample_size]

# %%
import transformers

pipeline=transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.float16,
    trust_remote_code=True,
    device_map="auto",

)

sequences = pipeline(
     lst_test_data_short,
     max_length=100,
     do_sample=True,
     top_k=10,
     num_return_sequences=1,
     eos_token_id=tokenizer.eos_token_id,
)

for ix ,seq in enumerate(sequences):
  print(ix,seq[0]['generated_text'])
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/utils/checkpoint.py:31: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 104, but `max_length` is set to 100. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# 0 Beard Trimmer for Men, Electric Trimmer and Shaver 14 in 1 Wet/Dry Waterproof USB Type-C Professional Hair Clippers Mustache Trimmer Body Nose Ear Face Trimmer Gifts for Men ->: Shaving & Hair Removal Products, Tools & Equipment ->: Shaving & Hair Clippers & Trimmers & Razors ->: Body Hair Remover & Shavers & Trimmers
# 1 JINMEI Hard EVA Dedicated Case for MJKJ RG351P Handheld Game Console Carrying Case ->: Kids' Electronics & Accessories Products ->: Kids' Electronics & Accessories: Electronics & Photo ->: Handheld Game Consoles & Accessories, Tabletop Game Consoles ->: Game Boxes & Cases ->: Kids' Handheld Game Consoles & Accessories ->:
# 2 Saiper Titanium Step Drill Bit 1/4" to 3/4" (9 Step Sizes) High Speed Steel Triangle Handle Step Drill Bits Drill Holes for Plastic, Aluminum, PV Plate ->: Cutting Tools and Supplies 1821244310: Cutting Tools & Supplies Product Type: Bit Product Name: Saiper Titanium Step Drill Bit
# 3 Upgraded Hose Replacement Compatible with Bissell Cleanview Swivel Pet Crosswave 2252 2489 2486 2254 22543 24899 1831 Vacuum Cleaner Part Number:203-8049 ->: Vacuum Cleaners & Floor Care Products Store Online ->: Household Essentials, K
# 4 Gillette Fusion5 ProGlide Razor Blades for Men with Precision Trimmer, Pack of 16 Refill Blades (Suitable for Mailbox) ->: Shaving & Hair Removal Products, Accessories & Tools: Beauty & Personal Care Products for Her & Beauty & Personal Care Products for Him ->: Men's Grooming & Personal Care Products ->: Men's Shaving & Grooming Products &
# 5 Suck UK | Stress Ball Fidget Toy | Stress Balls for Adults | Stress Relief for the Home Office | Gag Gifts & Cubicle Accessories | Funny Desk Decor & Office Supplies ->: Novelty Toys & Amusements ->: Funny, Silly Toys, Pranksters, & Fun ->: Fake Mustache Kits ->: Fake Mustache Kits for Men & Women ->: Men'
# 6 TA-VIGOR 4pcs 304 Stainless Steel Tube 5mm OD 0.4mm Wall Thickness 250mm Length, Seamless Straight Stainless Steel Round Tubing Stainless Steel Tube for Crafts ->: Hydraulics, Pneumatics & Plumbing Products, Tools & Hardware, Electrical Products, Industrial Supp
# 7 Rhinoceros Gift Rhino Lovers Gift Rhino Keeper Gift Spirit Animal Gift Rhino A Symbol Of Strength Wisdom Protection Keychain ->: Boys' Jewelry & Accessories, Men's Jewelry & Accessories, Men's & Women's Jewelry & Accessories, Men's ->: Men's Clothing, Shoes & Jewelry ->: Men's Accessories ->: Men's
# 8 Toddler Safety Leash Stroller Accessory for Child Safety Toddler Travel Accessory Links to Shopping Carts Wagons Backpacks Keep Kids Close ->: Baby Safety Products & Safety Gear Products ->: Baby Safety Products & Safety Gears for Toddlers, Toddlers Safety Products ->: Toddler Car Seats & Boosters Carrier ->: Toddler Safety Products
# 9 Rolio Pigments Resin Liquid Pigment Solid Colors - 18 vibrant colors for Epoxy Resin, Painting, DIY Art, Jewelry Making, Crafts Decorations, Garment Accessories - 0.33 oz/10 ml each ->: Painting, Drawing & Art Supplies, Paint & Paintbrushes ->: Arts, Crafts & S
# 10 Portable Spindle Sander Hand-Held Rubber Sanding Drum for Drill 4-1/2" x 1-1/2" and 4-1/2" x 1"(Red) ->: Abrasive & Finishing Products, Tools & Hardware Supplies & Accessories Online Store @ ->: Home & Garden Products Store ->: Tools & Equipment Products ->: Power & Electric Equipment Products
# 11 Vintage Botanical Prints | Stimulant Herbs Psychoactive Plants | Coffee, Tea, Coca, Mate | 8x10 Set of 4 Unframed ->: Wall Art, Wall Decor & MIRRORS Product Features Vintage botanical prints featuring 4 psychoactive plants, including Coffee, Tea, Coca, and Mate. everybody loves a good cup of coffee or a so
# 12 Ultrasonic Cleaner, 750ml Jewelry Cleaner Machine with Touch Control and Degas Mode, 46kHz Sonic Cleaner for Jewelry, Ring, Silver, Dentures, Eyeglasses and Watches ->: Lab & Scientific Products, Testing Equipment & Measurement Supplies ->: Testing Supplies & Cleaning Equipment 333845
# 13 8K USB C Laptop Docking Station with 2*DP&1*HDMI Ports,15 in 1 Hub Dock for Dual/Triple Monitors,6 *USB A/C Ports,100W PD,Ethernet,SD&TF,Audio,for Dell/HP/MacBook/Lenovo ->: Laptop Accessories, Computers & Tablets Products, Accessories & Supplies,
# 14 Breast Cancer Shirts For Women Pink Ribbon Sweatshirt Cancer Fight Awareness Shirt Faith Casual Long Sleeve Tops ->: Women's Clothing, Shoes & Jewelry ->: Women's Clothing & Accessories ->: Women's Tops & Blouses ->: Womens Sweatshirts & Hoodies ->: Cancer Clothing Product Description: -> Gender: Ladies
# 15 PERFECTSIGHT Switch Thumb Grips Caps, Cute Joystick Caps for Nintendo Switch/Switch Lite/Switch OLED, 4 PCS Thumbstick Cover, Analog Stick Button Cover for NS Joycon Controller Accessories, Pink ->: Video Games & Consoles Products, Games & Accessories Store @ GameStop > Product Details Customer Reviews: The product is very well made as advertised, very happy with
# 16 21.6V 5000mAh for Dyson V6 Battery Replacement Dyson Battery SV04 SV09 DC59 DC62 DC61 DC58 for Dyson Vacuum Tools ->: Power Tools & Hand Tools, Safety Equipment & Training Supplies, Hand & Power Tools ->: Power Hand & Hand Tools: Power Tool Batteries, Power Saw Batteries: Electron
# 17 Manhattan Toy Lovelies Lindy Lamb Stuffed Animal, 8" ->: Stuffed Animals & Plush Toys Product Features Product Description - Soft and huggable Lindy Lamb plush stuffed animal- 8 inches tall and weighs 0. everybody's favorite plush lamb is back with a brand new look and new features! Lovelies Lindy Lamb Stuffed Animal- Soft and Huggable- 8
# 18 Dorman 84785 Headlight Socket for H13/9008 Bulb Compatible with Select Models ->: Automotive Replacement Parts & Accessories Product Reviews 934312 34312 ->: Automotive Replacement Parts & Accessories: Automotive Replacement Parts & Accessories ->: Automotive Electrical Replacement Parts & Accessories ->: Automotive
# 19 Artdone 9 boxes Nail Rhinestones,Nail Gems Nail Diamonds,Nail Art Studs Nail Crystals Nail Sequins for Nails Kit with 1 Tweezers and 3 Pen for Nail Art Supplies Accessories ->: Foot, Hand & Nail Care Products Online: Beauty & Personal Care Products ->: Health & Wellness Products & Supplies ->: Hair Care Products & Supplies
# 20 leskep Trampoline Springs 5.5/6.5/7 inch - 24 & 36pack, Heavy Duty Replacement Trampoline Springs, Weather-Resistant, Includes Spring Tools for Easy Assembly ->: Sports & Outdoor Play Toys, Kids' Balls & Accessories, Kids' Indoor & Outdoor Games ->: Toys & Games Product Features: ->: Heavy D
# 21 Initial Letter B Dangle Hoop Earrings For Girls Hypoallergenic Zircon Chunky Thick Gold 925 Waterproof Earrings Small Gifts Jewelry For Women Kids ->: Girls' Jewelry & Accessories Product Features: - Made of 316L Stainless Steel, durable, waterproof; - Hypoallergenic, nickel-free, no irritation to skin; -
# 22 Acer Enduro T1 ET108-11A-80PZ Rugged Tablet, 8.0" WXGA IPS Touch, MediaTek MT8385 Octa-Core Processor, 4GB LPDDR4, 64GB eMMC, WiFi-5, Front 2MP Webcam, Rear 5MP Webcam, Handstrap, Android 9 Pie ->: Computers & Tablets Product
# 23 (5+4pcs) Buffing Polishing Pads 6 Inch and Wool Cutting Pad for Drill Buffer Attachment with Drill Adapter for Car Buffer Polisher Compounding, Polishing and Waxing ->: Car Care Products & Detailing Supplies->: Automotive Accessories, Replacement Parts & Accessories ->: Car Care, Detailing, Waxing & Paint Care Products, Accessories & Equip
# 24 Bucket Boss Gatemouth 16 Tool Bag in Brown, 60016, 15 liters(Brown) ->: Home Storage & Organization Products, Office Products, Home Improvement Products, Industrial Products & Safety Equipment, Home Storage & Organization Products ->: Storage Containers & Bins ->: Buckets & Cans ->: Plastic Storage Bins ->: Buckets ->: Brown
# 25 Dog Corgi Toddler Backpack for Boys Girls, Puppy Bone Kids Backpack for Preschool Kindergarten Toddler Bag with Chest Strap Waterproof Children Schoolbag Nursery Travel Bag ->: Baby Safety Products & Playground Equipment for Toddlers & Preschoolers ->: School Supplies & Accessories Products, Books & Entertainment Products, Games & Puzzles Products ->: Toys & Games
# 26 Jaxon Strap Gold Buckle Pin Genuine Padded Leather Watch Band- Premium Watchband Replacement for Men & Women- Watch Strap with Stitches Brown Black Color- Compatible Most Watches- Choose Size ->: Women's Watches & Accessories Products & Accessories Jewelry Watches & Accessories Men's Watches & Accessories ->: Women's Men's Watches & Accessories Men's Watches
# 27 NewWays Compatible with Apple Watch Band Upgraded Solid Business Stainless Steel Band for Apple iWatch ->: Wearable Technology Products Store ->: Accessories, Clothing & Shoes Products & Services ->: Women's Shoes, Clothing & Accessories Products & Services 000002140000000000000123456789101
# 28 Idea Nuova Disney Frozen Olaf Bean Bag Set (3-Piece), Large ->: Kids' Furniture & Accessories Store ->: Bedding & Bathroom Products ->: Kids' Room Furniture & Decor ->: Bedding & Bathroom Bedding & Accessories ->: Bean Bag Chairs & Ottomans ->: Bean Bag Chairs & Ottomans 111281317
# 29 Smart Watches Men Women Answer/Make Calls 1.96" Touch Screen Fitness Tracker with Heart Rate Blood Oxygen Blood Pressure Monitor 100+ Sports Modes Waterproof Calorie Watch Silver for Android IOS Phone ->: Wearable Technology & Accessories Product Features: -> 1.96" Full Color Touch Screen: The smart watch has a 1.96" touch screen, with a high definition display and
# 30 PLANTIONAL 2 Rolls Iron On Hem Tape: 1 Inch x 22 Yards Light Weight and Medium Weight Adhesive Web No Sewing Required Perfect for Bonding and Crafting Projects ->: Sewing Products & Supplies, Threads & Needles, Fabric Crafting Supplies & Tools, Thread, Threaders, & Needle Threaders ->: Sewing Supplies & Tools,
# 31 3M 1125-RW Duct Tape, 1.88 inches by 25 yards, 1 roll, Red & White ->: Industrial Adhesives, Sealants & Lubricants ->: Industrial Supplies & Equipment ->: Industrial Adhesives & Sealants 3M 1125-RW Duct Tape, 1.88 inches by 25 yards 5
# 32 Lick Mat for Dogs, Slow Feeder Licking Treat Mat, Anxiety Relief, Build Healthy Eating Habit, Boost Intelligence, Smell Training, Food-Grade Silicone Dry & Wet Food Pad with Suction Cup for Dogs Cats ->: Dog Supplies, Training & Grooming Products ->: Dogs & Puppies Products & Accessories, Cages, Kennels, Travelers
# 33 Rearview Mirror Radar Detector Mount, Aluminum Rearview Mirror Rod Radar Mount, for Cobra iRadar ESD SPX RAD 480i 450 380 7800BT Radar Detector ->: Car Electronics & Accessories Product Features: ->: GPS Navigation Systems ->: GPS Accessories & Mounts ->: Car GPS Systems ->: Vehicle Accessories
# 34 UA BIG LOGO POP JOGGER SET, Cosmic Blue, 6 ->: Boys' Clothing, Shoes & Accessories Products: Kids' Clothing, Shoes & Accessories ->: Kids' Fashion: Boys' ->: Boys' Clothing, Shoes & Accessories: Sportswear, Footwear, & Accessories ->: Boys' Shoes ->: Sneakers & Boosters ->: Sneakers

# %%
def correct_answer(ans):
  return(ans.split("->:")[1]).strip()

answers=[]
for ix,seq in enumerate(sequences):
  answers.append(correct_answer(seq[0]['generated_text']))
answers
# Out:
# ['Shaving & Hair Removal Products, Tools & Equipment',
#  "Kids' Electronics & Accessories Products",
#  'Cutting Tools and Supplies 1821244310: Cutting Tools & Supplies Product Type: Bit Product Name: Saiper Titanium Step Drill Bit',
#  'Vacuum Cleaners & Floor Care Products Store Online',
#  'Shaving & Hair Removal Products, Accessories & Tools: Beauty & Personal Care Products for Her & Beauty & Personal Care Products for Him',
#  'Novelty Toys & Amusements',
#  'Hydraulics, Pneumatics & Plumbing Products, Tools & Hardware, Electrical Products, Industrial Supp',
#  "Boys' Jewelry & Accessories, Men's Jewelry & Accessories, Men's & Women's Jewelry & Accessories, Men's",
#  'Baby Safety Products & Safety Gear Products',
#  'Painting, Drawing & Art Supplies, Paint & Paintbrushes',
#  'Abrasive & Finishing Products, Tools & Hardware Supplies & Accessories Online Store @',
#  'Wall Art, Wall Decor & MIRRORS Product Features Vintage botanical prints featuring 4 psychoactive plants, including Coffee, Tea, Coca, and Mate. everybody loves a good cup of coffee or a so',
#  'Lab & Scientific Products, Testing Equipment & Measurement Supplies',
#  'Laptop Accessories, Computers & Tablets Products, Accessories & Supplies,',
#  "Women's Clothing, Shoes & Jewelry",
#  'Video Games & Consoles Products, Games & Accessories Store @ GameStop > Product Details Customer Reviews: The product is very well made as advertised, very happy with',
#  'Power Tools & Hand Tools, Safety Equipment & Training Supplies, Hand & Power Tools',
#  "Stuffed Animals & Plush Toys Product Features Product Description - Soft and huggable Lindy Lamb plush stuffed animal- 8 inches tall and weighs 0. everybody's favorite plush lamb is back with a brand new look and new features! Lovelies Lindy Lamb Stuffed Animal- Soft and Huggable- 8",
#  'Automotive Replacement Parts & Accessories Product Reviews 934312 34312',
#  'Foot, Hand & Nail Care Products Online: Beauty & Personal Care Products',
#  "Sports & Outdoor Play Toys, Kids' Balls & Accessories, Kids' Indoor & Outdoor Games",
#  "Girls' Jewelry & Accessories Product Features: - Made of 316L Stainless Steel, durable, waterproof; - Hypoallergenic, nickel-free, no irritation to skin; -",
#  'Computers & Tablets Product',
#  'Car Care Products & Detailing Supplies',
#  'Home Storage & Organization Products, Office Products, Home Improvement Products, Industrial Products & Safety Equipment, Home Storage & Organization Products',
#  'Baby Safety Products & Playground Equipment for Toddlers & Preschoolers',
#  "Women's Watches & Accessories Products & Accessories Jewelry Watches & Accessories Men's Watches & Accessories",
#  'Wearable Technology Products Store',
#  "Kids' Furniture & Accessories Store",
#  'Wearable Technology & Accessories Product Features: -> 1.96" Full Color Touch Screen: The smart watch has a 1.96" touch screen, with a high definition display and',
#  'Sewing Products & Supplies, Threads & Needles, Fabric Crafting Supplies & Tools, Thread, Threaders, & Needle Threaders',
#  'Industrial Adhesives, Sealants & Lubricants',
#  'Dog Supplies, Training & Grooming Products',
#  'Car Electronics & Accessories Product Features:',
#  "Boys' Clothing, Shoes & Accessories Products: Kids' Clothing, Shoes & Accessories"]

# %%
df_evaluate=test_df.iloc[:sample_size][['title','category_name']]

df_evaluate=df_evaluate.reset_index(drop=True)

df_evaluate['category_predicted']=answers

df_evaluate
# Out:
#                                                 title  \
# 0   Beard Trimmer for Men, Electric Trimmer and Sh...
# 1   JINMEI Hard EVA Dedicated Case for MJKJ RG351P...
# 2   Saiper Titanium Step Drill Bit 1/4" to 3/4" (9...
# 3   Upgraded Hose Replacement Compatible with Biss...
# 4   Gillette Fusion5 ProGlide Razor Blades for Men...
# 5   Suck UK | Stress Ball Fidget Toy | Stress Ball...
# 6   TA-VIGOR 4pcs 304 Stainless Steel Tube 5mm OD ...
# 7   Rhinoceros Gift Rhino Lovers Gift Rhino Keeper...
# 8   Toddler Safety Leash Stroller Accessory for Ch...
# 9   Rolio Pigments Resin Liquid Pigment Solid Colo...
# 10  Portable Spindle Sander Hand-Held Rubber Sandi...
# 11  Vintage Botanical Prints | Stimulant Herbs Psy...
# 12  Ultrasonic Cleaner, 750ml Jewelry Cleaner Mach...
# 13  8K USB C Laptop Docking Station with 2*DP&1*HD...
# 14  Breast Cancer Shirts For Women Pink Ribbon Swe...
# 15  PERFECTSIGHT Switch Thumb Grips Caps, Cute Joy...
# 16  21.6V 5000mAh for Dyson V6 Battery Replacement...
# 17  Manhattan Toy Lovelies Lindy Lamb Stuffed Anim...
# 18  Dorman 84785 Headlight Socket for H13/9008 Bul...
# 19  Artdone 9 boxes Nail Rhinestones,Nail Gems Nai...
# 20  leskep Trampoline Springs 5.5/6.5/7 inch - 24 ...
# 21  Initial Letter B Dangle Hoop Earrings For Girl...
# 22  Acer Enduro T1 ET108-11A-80PZ Rugged Tablet, 8...
# 23  (5+4pcs) Buffing Polishing Pads 6 Inch and Woo...
# 24  Bucket Boss Gatemouth 16 Tool Bag in Brown, 60...
# 25  Dog Corgi Toddler Backpack for Boys Girls, Pup...
# 26  Jaxon Strap Gold Buckle Pin Genuine Padded Lea...
# 27  NewWays Compatible with Apple Watch Band Upgra...
# 28  Idea Nuova Disney Frozen Olaf Bean Bag Set (3-...
# 29  Smart Watches Men Women Answer/Make Calls 1.96...
# 30  PLANTIONAL 2 Rolls Iron On Hem Tape: 1 Inch x ...
# 31  3M 1125-RW Duct Tape, 1.88 inches by 25 yards,...
# 32  Lick Mat for Dogs, Slow Feeder Licking Treat M...
# 33  Rearview Mirror Radar Detector Mount, Aluminum...
# 34         UA BIG LOGO POP JOGGER SET, Cosmic Blue, 6
#
#                                   category_name  \
# 0               Shaving & Hair Removal Products
# 1                             Kids' Electronics
# 2                                 Cutting Tools
# 3                  Vacuum Cleaners & Floor Care
# 4               Shaving & Hair Removal Products
# 5                     Novelty Toys & Amusements
# 6             Hydraulics, Pneumatics & Plumbing
# 7                                 Boys' Jewelry
# 8                          Baby Safety Products
# 9              Painting, Drawing & Art Supplies
# 10                Abrasive & Finishing Products
# 11                                     Wall Art
# 12                    Lab & Scientific Products
# 13                           Laptop Accessories
# 14                             Women's Clothing
# 15                                  Video Games
# 16                     Power Tools & Hand Tools
# 17                 Stuffed Animals & Plush Toys
# 18                 Automotive Replacement Parts
# 19              Foot, Hand & Nail Care Products
# 20                   Sports & Outdoor Play Toys
# 21                               Girls' Jewelry
# 22                          Computers & Tablets
# 23                                     Car Care
# 24                  Home Storage & Organization
# 25                         Baby Safety Products
# 26                              Women's Watches
# 27                          Wearable Technology
# 28                              Kids' Furniture
# 29                          Wearable Technology
# 30                              Sewing Products
# 31  Industrial Adhesives, Sealants & Lubricants
# 32                                 Dog Supplies
# 33                Car Electronics & Accessories
# 34                               Boys' Clothing
#
#                                    category_predicted
# 0   Shaving & Hair Removal Products, Tools & Equip...
# 1            Kids' Electronics & Accessories Products
# 2   Cutting Tools and Supplies 1821244310: Cutting...
# 3   Vacuum Cleaners & Floor Care Products Store On...
# 4   Shaving & Hair Removal Products, Accessories &...
# 5                           Novelty Toys & Amusements
# 6   Hydraulics, Pneumatics & Plumbing Products, To...
# 7   Boys' Jewelry & Accessories, Men's Jewelry & A...
# 8         Baby Safety Products & Safety Gear Products
# 9   Painting, Drawing & Art Supplies, Paint & Pain...
# 10  Abrasive & Finishing Products, Tools & Hardwar...
# 11  Wall Art, Wall Decor & MIRRORS Product Feature...
# 12  Lab & Scientific Products, Testing Equipment &...
# 13  Laptop Accessories, Computers & Tablets Produc...
# 14                  Women's Clothing, Shoes & Jewelry
# 15  Video Games & Consoles Products, Games & Acces...
# 16  Power Tools & Hand Tools, Safety Equipment & T...
# 17  Stuffed Animals & Plush Toys Product Features ...
# 18  Automotive Replacement Parts & Accessories Pro...
# 19  Foot, Hand & Nail Care Products Online: Beauty...
# 20  Sports & Outdoor Play Toys, Kids' Balls & Acce...
# 21  Girls' Jewelry & Accessories Product Features:...
# 22                        Computers & Tablets Product
# 23             Car Care Products & Detailing Supplies
# 24  Home Storage & Organization Products, Office P...
# 25  Baby Safety Products & Playground Equipment fo...
# 26  Women's Watches & Accessories Products & Acces...
# 27                 Wearable Technology Products Store
# 28                Kids' Furniture & Accessories Store
# 29  Wearable Technology & Accessories Product Feat...
# 30  Sewing Products & Supplies, Threads & Needles,...
# 31        Industrial Adhesives, Sealants & Lubricants
# 32         Dog Supplies, Training & Grooming Products
# 33    Car Electronics & Accessories Product Features:
# 34  Boys' Clothing, Shoes & Accessories Products: ...
